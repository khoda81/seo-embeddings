# %%
# Define the URL where Label Studio is accessible
import os
import dotenv

dotenv.load_dotenv()

LABEL_STUDIO_URL = "http://185.8.172.121:8080/"
# API key is available at the Account & Settings page in Label Studio UI
LABEL_STUDIO_API_KEY = os.environ["LABELSTUDIO_TOKEN"]

# %%
import os
import pandas as pd

DATA_DIR = "dataset/href_queries"

# Collect text files
files = [f for f in os.listdir(DATA_DIR) if f.endswith(".txt")]


# Generator of DataFrames — avoids building large Python lists
def load_file(path, filename):
    return pd.read_csv(
        path,
        header=None,  # no header row
        names=["query"],
        engine="python",  # safe for \n separation
        encoding="utf-8",
    ).assign(source=filename)


# Concatenate all at once (pandas handles internal chunking efficiently)
df = pd.concat(
    (load_file(os.path.join(DATA_DIR, f), f) for f in files),
    ignore_index=True,
)

print(df.info())

df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   query   5000 non-null   object
#  1   source  5000 non-null   object
# dtypes: object(2)
# memory usage: 78.3+ KB
# None
#                        query                       source
# 0     خرید لباس مجلسی پسرانه   keywords-04-tir-random.txt
# 1            امداد خودرو رنو   keywords-04-tir-random.txt
# 2                     کراتین   keywords-04-tir-random.txt
# 3           شکایت برای ارثیه   keywords-04-tir-random.txt
# 4         لگو فانتزی دخترانه   keywords-04-tir-random.txt
# ...                      ...                          ...
# 4995               تور سوئیس  keywords-08-aban-random.txt
# 4996          کاشت موی طبیعی  keywords-08-aban-random.txt
# 4997              نوار نقاله  keywords-08-aban-random.txt
# 4998       ضایعات الکترونیکی  keywords-08-aban-random.txt
# 4999        کلاس‌های بارداری  keywords-08-aban-random.txt
#
# [5000 rows x 2 columns]

# %%
import pandas as pd
import requests
import json
import random
import time
from urllib.parse import quote
import tqdm.auto as tqdm

# === CONFIG ===
INPUT_CSV = "dataset/queries (1).csv"
OUTPUT_JSON = "dataset/unannotated_dataset.json"
API_URL = "http://185.8.172.121:8000/similar-keywords?query={}&top_k=64"
SAMPLES_PER_QUERY = 10
SLEEP_BETWEEN_REQUESTS = 0.0  # seconds, to avoid hammering the API

# === LOAD QUERIES ===
df = pd.read_csv(INPUT_CSV)
queries = df.dropna()

dataset = []

for i, query in tqdm.tqdm(queries.iterrows(), unit="queries", total=len(df)):
    try:
        url = API_URL.format(quote(query["keyword"]))
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        results = response.json()

        if not results:
            continue

        # sample up to 10 results
        options = random.sample(results, min(SAMPLES_PER_QUERY, len(results)))

        entry = {
            "query": query,
            "site_count": query["site_count"],
            "options": [
                {"value": item["keyword"], "score": item["similarity"]}
                for item in options
            ],
        }
        dataset.append(entry)

        # print(f"[{i + 1}/{len(queries)}] ✅ {query} ({len(sampled)} options)")

    except Exception as e:
        print(f"[{i + 1}/{len(queries)}] ⚠️ Error for '{query}': {e}")

    time.sleep(SLEEP_BETWEEN_REQUESTS)
# Out:
#   0%|          | 0/1024 [00:00<?, ?queries/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 25
#      23 try:
#      24     url = API_URL.format(quote(query["keyword"]))
# ---> 25     response = requests.get(url, timeout=10)
#      26     response.raise_for_status()
#      27     results = response.json()
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df.to_csv("queries/href_queries.csv")

# %%
import pandas as pd
import requests
import json
import random
from urllib.parse import quote
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.auto import tqdm

# === CONFIG ===
INPUT_CSV = "dataset/queries (1).csv"
OUTPUT_JSON = "dataset/unannotated_dataset.json"
API_URL = "http://185.8.172.121:8000/similar-keywords?query={}&top_k=64"
SAMPLES_PER_QUERY = 10
MAX_WORKERS = 4  # you can safely increase this to 64 or even 128 if API is fast

# === LOAD QUERIES ===
df = pd.read_csv(INPUT_CSV).dropna(subset=["keyword"])
queries = df.to_dict("records")


def fetch(query_row: dict):
    keyword = query_row["keyword"]
    while True:
        try:
            url = API_URL.format(quote(keyword))
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            results = response.json()
            if not results:
                return None

            sampled = random.sample(results, min(SAMPLES_PER_QUERY, len(results)))
            sampled.sort(key=lambda e: e["similarity"], reverse=True)

            return {
                "query": keyword,
                "site_count": query_row["site_count"],
                "options": [
                    {"value": item["keyword"], "score": item["similarity"]}
                    for item in sampled
                ],
            }

        except Exception as e:
            print("Error:", e)
            continue
            # return {"query": keyword, "error": str(e)}


# === MULTITHREADED FETCH ===
dataset = []
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = [executor.submit(fetch, q) for q in queries]
    for f in tqdm(as_completed(futures), total=len(futures), unit="queries"):
        result = f.result()
        if result and "error" not in result:
            dataset.append(result)
# Out:
#   0%|          | 0/1024 [00:00<?, ?queries/s]
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out. (read timeout=10)
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out. (read timeout=10)
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out. (read timeout=10)
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out. (read timeout=10)
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out. (read timeout=10)
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: HTTPConnectionPool(host='185.8.172.121', port=8000): Read timed out.
# Error: 403 Client Error: Forbidden for url: http://185.8.172.121:8000/similar-keywords?query=%D8%B3%DA%A9%D8%B3%20%D8%AA%D8%B1%D8%B3%D9%86%D8%A7%DA%A9&top_k=64
# Error: 403 Client Error: Forbidden for url: http://185.8.172.121:8000/similar-keywords?query=%D8%B3%DA%A9%D8%B3%20%D9%BE%D9%84%DB%8C%D8%B3&top_k=64
# Error: 403 Client Error: Forbidden for url: http://185.8.172.121:8000/similar-keywords?query=%D8%AF%D8%A7%D8%B3%D8%AA%D8%A7%D9%86%20%D8%B4%D9%87%D9%88%D8%A7%D9%86%DB%8C&top_k=64
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error: 500 Server Error: Internal Server Error for url: http://185.8.172.121:8000/similar-keywords?query=%D9%BE%D8%B1%D9%88%D9%81%D8%A7%DB%8C%D9%84%20%D8%B4%D8%A8%20%D9%82%D8%AF%D8%B1%20%D8%AC%D8%AF%DB%8C%D8%AF&top_k=64
# Error: 500 Server Error: Internal Server Error for url: http://185.8.172.121:8000/similar-keywords?query=%D9%85%D8%A7%D9%84%DB%8C%D8%A7%D8%AA%20%D8%B7%D9%84%D8%A7&top_k=64
# Error: 500 Server Error: Internal Server Error for url: http://185.8.172.121:8000/similar-keywords?query=%D8%A2%DB%8C%D8%A7%20%D8%A7%D9%85%D8%B1%D9%88%D8%B2%20%D8%B1%D9%88%D8%B2%20%D9%BE%D8%AF%D8%B1%20%D8%A7%D8%B3%D8%AA&top_k=64
# Error: 500 Server Error: Internal Server Error for url: http://185.8.172.121:8000/similar-keywords?query=%D8%A7%D8%B1%D8%B4%20%D9%81%D9%84%D8%A7%D8%AD%D8%AA%20%D9%BE%DB%8C%D8%B4%D9%87&top_k=64
# Error: 500 Server Error: Internal Server Error for url: http://185.8.172.121:8000/similar-keywords?query=%D8%B3%D8%A7%D9%88%D8%AA%E2%80%8C%D9%87%D9%85%D9%BE%D8%AA%D9%88%D9%86%20%D9%85%D9%82%D8%A7%D8%A8%D9%84%20%D9%84%DB%8C%D9%88%D8%B1%D9%BE%D9%88%D9%84&top_k=64

# %%
# === SAVE OUTPUT ===
with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
    json.dump(dataset, f, ensure_ascii=False, indent=2)

print(f"\n✅ Saved {len(dataset)} items to {OUTPUT_JSON}")
# Out:
# ✅ Saved 1024 items to dataset/unannotated_dataset.json

# %%
# Out:
# username: 20.mahdikh.0
# email: 20.mahdikh.0@gmail.com

# %%
from openai import project


ls_client.tasks.create(
    data={"query":},
    project=project.id,
)

# %%
import asyncio
import aiohttp
import pandas as pd
import random
import os
import pandas as pd
import dotenv
from urllib.parse import quote

# import tqdm.auto as tqdm
from label_studio_sdk import AsyncLabelStudio

dotenv.load_dotenv()


# === CONFIG ===
DATA_DIR = "dataset/href_queries"
LABEL_STUDIO_URL = "http://185.8.172.121:8080/"
# API key is available at the Account & Settings page in Label Studio UI
LABEL_STUDIO_API_KEY = os.environ["LABELSTUDIO_TOKEN"]

API_URL = "http://185.8.172.121:8000/similar-keywords?query={}&top_k=64"
SAMPLES_PER_QUERY = 10
MAX_WORKERS = 4  # you can safely increase this to 64 or even 128 if API is fast


# Connect to the Label Studio API
ls_client = AsyncLabelStudio(
    base_url=LABEL_STUDIO_URL,
    api_key=LABEL_STUDIO_API_KEY,
)

project = await ls_client.projects.get(id=1)

# A basic request to verify connection is working
me = await ls_client.users.whoami()

print("username:", me.username)
print("email:", me.email)


# === LOAD QUERIES ===

# Collect text files
files = [f for f in os.listdir(DATA_DIR) if f.endswith(".txt")]


# Generator of DataFrames — avoids building large Python lists
def load_file(path, filename):
    return pd.read_csv(
        path,
        header=None,  # no header row
        names=["query"],
        engine="python",  # safe for \n separation
        encoding="utf-8",
    ).assign(source=filename)


# Concatenate all at once (pandas handles internal chunking efficiently)
queries_df = pd.concat(
    (load_file(os.path.join(DATA_DIR, f), f) for f in files),
    ignore_index=True,
)


async def fetch_similar(
    session: aiohttp.ClientSession, query: str, top_k=10
) -> list[dict[str, str]]:
    url = API_URL.format(quote(query))
    response = await session.get(url, timeout=10)
    response.raise_for_status()
    results = await response.json()
    if not results:
        raise ValueError(f"Server returned no response for `{query}`: {results}")

    if top_k < len(results):
        results = random.sample(results, min(top_k, len(results)))

    results.sort(key=lambda e: e["similarity"], reverse=True)
    return results


async def create_task(
    query_row: dict[str, str],
    options: list[dict[str, str]],
):
    return await ls_client.tasks.create(
        data={
            "options": [
                {
                    "value": item["keyword"],
                    "score": item["similarity"],
                    "hint": "translation I guess",
                }
                for item in options
            ],
            **query_row,
        },
        project=project.id,
    )


async def create_task_from_query(
    session: aiohttp.ClientSession,
    query_row: dict[str, str],
    sem: asyncio.Semaphore,
):
    while True:
        async with sem:
            try:
                options = await fetch_similar(
                    session,
                    query_row["query"],
                    top_k=SAMPLES_PER_QUERY,
                )
                break

            except Exception as e:
                print(f"Retrying query {query_row}: {e}")
                await asyncio.sleep(3)

    while True:
        try:
            return await create_task(
                query_row=query_row,
                options=options,
            )

        except Exception as e:
            print(f"Retrying task task creation {query_row}: {e}")
            await asyncio.sleep(3)
# Out:
# username: 20.mahdikh.0
# email: 20.mahdikh.0@gmail.com

# %%
import asyncio
import os

import aiohttp
import dotenv
import tqdm.asyncio
from googletrans import Translator
from label_studio_sdk import AsyncLabelStudio, LabelStudio, RoleBasedTask

# import tqdm.auto as tqdm

dotenv.load_dotenv()


# === CONFIG ===
LABEL_STUDIO_URL = "http://185.8.172.121:8080/"
# API key is available at the Account & Settings page in Label Studio UI
LABEL_STUDIO_API_KEY = os.environ["LABELSTUDIO_TOKEN"]

MAX_WORKERS = 4  # you can safely increase this to 64 or even 128 if API is fast


# Connect to the Label Studio API
als_client = AsyncLabelStudio(
    base_url=LABEL_STUDIO_URL,
    api_key=LABEL_STUDIO_API_KEY,
)

# Connect to the Label Studio API
ls_client = LabelStudio(
    base_url=LABEL_STUDIO_URL,
    api_key=LABEL_STUDIO_API_KEY,
)


project = ls_client.projects.get(id=1)
print(project)
tasks = ls_client.tasks.list(project=project.id)
annotations = []

# A basic request to verify connection is working
me = ls_client.users.whoami()

print("username:", me.username)
print("email:", me.email)

translator = Translator()


async def enrich_translations(task: RoleBasedTask):
    translations = await translator.translate(
        [entry["value"] for entry in task.data["options"]],
        src="auto",
        dest="fa",
    )

    for entry, translation in zip(task.data["options"], translations):
        entry["hint"] = translation.text

    return task


async def translate_task(
    task: RoleBasedTask,
    sem: asyncio.Semaphore,
):
    annotations.extend(task.annotations)
    if task.annotations or all("hint" in cand for cand in task.data["options"]):
        return

    while True:
        async with sem:
            try:
                task = await enrich_translations(task)
                break

            except Exception as e:
                print(f"Translating {task.id}: {e}")
                await asyncio.sleep(3)

    while True:
        try:
            return await als_client.tasks.update(
                task.id, project=project.id, data=task.data
            )

        except Exception as e:
            print(f"Retrying task update {task.id}: {e}")
            await asyncio.sleep(3)


tasks = list(ls_client.tasks.list(project=project.id))


sem = asyncio.Semaphore(MAX_WORKERS)  # concurrency control
async with aiohttp.ClientSession() as session:
    # Iterate asynchronously
    for coro in tqdm.asyncio.tqdm.as_completed(
        [translate_task(t, sem) for t in tasks], unit="tasks"
    ):
        try:
            result = await coro

        except Exception as e:
            print("❌ Error:", e)
# Out:
# agreement_threshold=None allow_stream=None annotation_limit_count=None annotation_limit_percent=None annotator_evaluation_minimum_score=None annotator_evaluation_minimum_tasks=None assignment_settings=None color='#FFFFFF' comment_classification_config=None config_has_control_tags=True config_suitable_for_bulk_annotation=False control_weights={'rel': {'overall': 1.0, 'type': 'Choices', 'labels': {}}} created_at=datetime.datetime(2025, 11, 8, 6, 46, 8, 364936, tzinfo=datetime.timezone.utc) created_by=UserSimple(avatar=None, email='20.mahdikh.0@gmail.com', first_name='', id=1, last_name='') custom_script=None custom_task_lock_ttl=None data_types=None description='' duplication_done=None duplication_status=None enable_empty_annotation=True evaluate_predictions_automatically=False expert_instruction='For each query, you are given a few sample keywords and your job is to select and check the options that are relevant and uncheck the ones that are irrelevant.' finished_task_number=186 ground_truth_number=0 id=1 is_draft=False is_published=False label_config='<View>\n  <Header value="Query" size="5"/>\n  <Text name="q" value="$query"/>\n  <Header value="Candidates" size="5"/>\n  <Choices name="rel" toName="q" selection="checkbox" choice="multiple" value="$options" layout="vertical" />\n</View>' max_additional_annotators_assignable=None maximum_annotations=1 members=None members_count=None min_annotations_to_start_training=0 model_version='mahdi' num_tasks_with_annotations=186 organization=1 overlap_cohort_percentage=100 parsed_label_config={'rel': {'type': 'Choices', 'to_name': ['q'], 'dynamic_labels': True, 'inputs': [{'type': 'Text', 'valueType': None, 'value': 'query'}], 'labels': [], 'labels_attrs': {}}} pause_on_failed_annotator_evaluation=None pinned_at=None prompts=None queue_done=29 queue_left=None queue_total=5861 ready=None rejected=None require_comment_on_skip=None reveal_preannotations_interactively=False review_settings=None review_total_tasks=None reviewed_number=None reviewer_queue_total=None sampling='Uniform sampling' show_annotation_history=False show_collab_predictions=True show_ground_truth_first=False show_instruction=True show_overlap_first=False show_skip_button=True show_unused_data_columns_to_annotators=None skip_queue='REQUEUE_FOR_OTHERS' skipped_annotations_number=17 start_training_on_annotation_update=False task_data_login=None task_data_password=None task_number=6019 title='Embedding Samples' total_annotations_number=186 total_predictions_number=1510 useful_annotation_number=186 workspace=None workspace_title=None
# username: 20.mahdikh.0
# email: 20.mahdikh.0@gmail.com
#  18%|█▊        | 1104/6019 [05:35<33:15,  2.46tasks/s]
# Translating 2405: Server disconnected
# Translating 2406: Server disconnected
# Translating 3855: Server disconnected
# Translating 180: Server disconnected
# Retrying task update 5870: Server disconnected without sending a response.
# Retrying task update 3853: Server disconnected without sending a response.
#  46%|████▋     | 2798/6019 [16:23<41:37,  1.29tasks/s]
# Translating 6606:
# Translating 6605:
# Translating 2574:
# Translating 4590:
# Retrying task update 4589:
# Translating 2575: [Errno 11001] getaddrinfo failed
# Translating 4591:
# Translating 4592: [Errno 11001] getaddrinfo failed
# Translating 6607:
# Translating 2576: [Errno 11001] getaddrinfo failed
# Translating 6608:
# Translating 4593: [Errno 11001] getaddrinfo failed
# Translating 2577:
# Retrying task update 4589:
# Translating 6609:
# Translating 2578: [Errno 11001] getaddrinfo failed
# Translating 6610:
# Translating 4594:
# Translating 4595:
# Translating 2579:
# Translating 4596:
# Retrying task update 4589:
# Translating 6612: [Errno 11001] getaddrinfo failed
# Translating 6611:
# Translating 2580: [Errno 11001] getaddrinfo failed
# Translating 4597: [Errno 11001] getaddrinfo failed
# Translating 2581:
# Translating 6613:
# Translating 2582:
# Retrying task update 4589: Server disconnected without sending a response.
# Translating 4598:
# Translating 6614:
# Translating 4599: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 2583: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 2584: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6615: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 4600: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6616: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 2585: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 4601: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6617: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 2586: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 4602: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6618: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Retrying task update 4589: All connection attempts failed
# Translating 2587: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 4603: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6619: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 2588: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 4604: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6620: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 2589: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 4605: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6621: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 2590: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 4606: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# Translating 6622: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'translate.googleapis.com'. (_ssl.c:1000)
# 100%|██████████| 6019/6019 [1:02:12<00:00,  1.61tasks/s]

# %%
tasks = list(ls_client.tasks.list(project=project.id))

# %%
annotations = []
for task in tasks:
    annotations.extend(task.annotations)

# %%
import pandas as pd


annotations_df = pd.DataFrame(annotations)

# %%
annotations_df["created_at_dt"] = pd.to_datetime(annotations_df["created_at"])
annotations_df["updated_at_dt"] = pd.to_datetime(annotations_df["updated_at"])

# %%
import random

random_task = random.choice(tasks)

# %%
random_task.annotations
# Out:
# [{'id': 414,
#   'result': [{'value': {'choices': ['دستگاه لیزر',
#       'بهترین دستگاه لیزر',
#       'لیزر خال',
#       'لیزر جای جوش',
#       'لیزر فرکشنال',
#       'دستگاه لیزر تیتانیوم',
#       'دستگاه لیزر بدن']},
#     'id': 'xX8w8WKIlj',
#     'from_name': 'rel',
#     'to_name': 'q',
#     'type': 'choices',
#     'origin': 'manual'}],
#   'created_username': ' rafatesmino@gmail.com, 5',
#   'created_ago': '5\xa0hours, 34\xa0minutes',
#   'completed_by': 5,
#   'was_cancelled': False,
#   'ground_truth': False,
#   'created_at': '2025-11-15T08:53:12.154835Z',
#   'updated_at': '2025-11-15T08:53:12.154879Z',
#   'draft_created_at': '2025-11-15T08:50:53.987440Z',
#   'lead_time': 149.639,
#   'import_id': None,
#   'last_action': None,
#   'bulk_created': False,
#   'task': 2102,
#   'project': 1,
#   'updated_by': 5,
#   'parent_prediction': None,
#   'parent_annotation': None,
#   'last_created_by': None}]

# %%
import datetime
import plotly.express as px

threshold = datetime.datetime.now(datetime.timezone.utc).replace(
    hour=9, minute=0, second=0, microsecond=0
)

is_today = annotations_df["created_at_dt"] > threshold


fig = px.histogram(
    annotations_df[is_today],
    x="created_at_dt",
    color="created_username",
    nbins=100,  # adjust bin count for smoothness
    title="Annotation Density Over Time by User",
)

fig.update_layout(
    bargap=0.05,
    xaxis_title="Time",
    yaxis_title="Number of Annotations",
)

fig.show()

# %%
import plotly.express as px

fig = px.density_heatmap(
    annotations_df,
    x="created_at_dt",
    y="created_username",
    color_continuous_scale="Viridis",
    title="Annotation Density Heatmap",
)

fig.update_layout(
    xaxis_title="Time",
    yaxis_title="User",
)
fig.show()

# %%
df = annotations_df.copy()
df["timestamp"] = df["created_at_dt"].astype("int64") // 10**9  # convert to seconds

# Count events per minute per user
df_resampled = (
    df.set_index("created_at_dt")
    .groupby("created_username")
    .resample("1min")["created_username"]
    .count()
    .rename("count")
    .reset_index()
)

fig = px.line(
    df_resampled,
    x="created_at_dt",
    y="count",
    color="created_username",
    title="Smoothed Annotation Density Over Time",
)

fig.show()

# %%
from googletrans import Translator

import asyncio

from label_studio_sdk import RoleBasedTask


translator = Translator()


async def enrich_translations(task: RoleBasedTask):
    translations = await translator.translate(
        [entry["value"] for entry in task.data["options"]],
        src="auto",
        dest="fa",
    )

    for entry, translation in zip(task.data["options"], translations):
        entry["hint"] = translation.text

    return task

# %%
await enrich_translations(task)

print(task.data["options"])
# Out:
# [{'value': 'מהגרים', 'score': 0.8278806, 'hint': 'مهاجران'}, {'value': 'imigration', 'score': 0.800049, 'hint': 'فراموش کردن'}, {'value': 'مهاجرین', 'score': 0.7876773, 'hint': 'مهاجرین'}, {'value': 'سازمان مهاجرتی', 'score': 0.7745429, 'hint': 'سازمان مهاجرتی'}, {'value': 'moving abroad', 'score': 0.7697719, 'hint': 'حرکت به خارج از کشور'}, {'value': 'expat or immigrant', 'score': 0.76735723, 'hint': 'مهاجر یا مهاجر'}, {'value': 'موسسه مهاجرتی تراست', 'score': 0.74778056, 'hint': 'موسسه مهاجرتی تراست'}, {'value': 'مهاجرت بدون پول', 'score': 0.7448804, 'hint': 'مهاجرت بدون پول'}, {'value': 'الهجرة الى اوروبا', 'score': 0.74148244, 'hint': 'مهاجرت به اروپا'}, {'value': 'immigration:', 'score': 0.7411676, 'hint': 'مهاجرت:'}]

# %%
tasks = ls_client.tasks.list(project=project.id)
annotations = []

# %%
import tqdm.auto as tqdm


for task in tqdm.tqdm(tasks, total=):
    annotations.extend(task.annotations)
    if task.annotations or all("hint" in cand for cand in task.data["options"]):
        continue

    print(task)
    task = await enrich_translations(task)
    await als_client.tasks.update(task.id, project=project.id, data=task.data)
    break

print(task.id)
# Out:
# 0it [00:00, ?it/s]
# agreement=None agreement_selected=None annotations=[] annotations_ids='' annotations_results='' annotators=[] annotators_count=None avg_lead_time=None cancelled_annotations=0 comment_authors=[] comment_authors_count=None comment_count=0 comments=None completed_at=None created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747569, tzinfo=datetime.timezone.utc) data={'query': 'ضبط صوت سامسونگ', 'site_count': 24, 'options': [{'value': 'ضبط صوت سامسونگ', 'score': 0.99999994}, {'value': 'وصل كردن گوشي به تلويزيون سامسونگ', 'score': 0.8253835}, {'value': 'باز كردن رمز گوشي سامسونگ', 'score': 0.8237331}, {'value': 'وصل كردن گوشي سامسونگ به تلویزیون', 'score': 0.8068063}, {'value': 'پخش کننده موسیقی سامسونگ', 'score': 0.77631205}, {'value': 'voice focus samsung', 'score': 0.77151215}, {'value': 'نصب شنود روی گوشی', 'score': 0.7510103}, {'value': 'call ضبط مکالمه دو طرفه گوشی سامسونگ', 'score': 0.7452122}, {'value': 'قيمت گوشي سامسونگ', 'score': 0.7358978}, {'value': 'دانلود برنامه موسیقی سامسونگ', 'score': 0.72821105}]} draft_exists=True drafts=[LseTaskDraftsItem(created_at=datetime.datetime(2025, 11, 12, 9, 31, 22, 811431, tzinfo=datetime.timezone.utc), result=[{'value': {'choices': ['ضبط صوت سامسونگ', 'پخش کننده موسیقی سامسونگ', 'call ضبط مکالمه دو طرفه گوشی سامسونگ']}, 'id': '1d02117a-6054-4e92-9e9f-ffbfaed38396', 'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'origin': 'prediction-changed'}], updated_at=datetime.datetime(2025, 11, 12, 9, 31, 22, 811465, tzinfo=datetime.timezone.utc), id=86, user='20.mahdikh.0@gmail.com', created_username='20.mahdikh.0@gmail.com, 1', created_ago='2\xa0days, 21\xa0hours', lead_time=63.033, was_postponed=False, import_id=None, task=17, annotation=None)] file_upload='a5962bf1-annotated_results.json' ground_truth=None id=17 inner_id=17 is_labeled=False last_comment_updated_at=None meta={} overlap=1 precomputed_agreement=None predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974455, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['ضبط صوت سامسونگ', 'پخش کننده موسیقی سامسونگ', 'دانلود برنامه موسیقی سامسونگ']}}], score=None, task=17, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974463, tzinfo=datetime.timezone.utc), id=2066, created_ago='4\xa0days, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0), LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 296352, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='mahdi', project=1, result=[{'id': '32e3f974-b620-49fa-9509-3146ca886277', 'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['وصل كردن گوشي سامسونگ به تلویزیون', 'ضبط صوت سامسونگ']}}], score=0.0, task=17, updated_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 296385, tzinfo=datetime.timezone.utc), id=3074, created_ago='3\xa0days', cluster=None, neighbors=None, mislabeling=0.0), LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 12, 7, 18, 23, 584029, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='mahdi', project=1, result=[{'id': '1d02117a-6054-4e92-9e9f-ffbfaed38396', 'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['ضبط صوت سامسونگ', 'call ضبط مکالمه دو طرفه گوشی سامسونگ']}}], score=0.3333333333333333, task=17, updated_at=datetime.datetime(2025, 11, 12, 7, 18, 23, 584063, tzinfo=datetime.timezone.utc), id=3182, created_ago='2\xa0days, 23\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)] predictions_model_versions='mahdi,undefined' predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0636\\u0628\\u0637 \\u0635\\u0648\\u062a \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af, \\u067e\\u062e\\u0634 \\u06a9\\u0646\\u0646\\u062f\\u0647 \\u0645\\u0648\\u0633\\u06cc\\u0642\\u06cc \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af, \ ...
# 17

# %%
task

# %%
task.id
# Out:
# 17

# %%
len(finished)
# Out:
# 5802

# %%
tasks = await ls_client.tasks.list(project=project.id, include=["data"])

while tasks.has_next:
    for task in tasks.items:
        finished.add(task.data["query"])

    tasks = await tasks.get_next()
# Out:
# c:\Users\20mah\anaconda3\envs\rl\Lib\json\decoder.py:353: RuntimeWarning: coroutine 'AsyncProjectsClientExt.get' was never awaited
#   obj, end = self.scan_once(s, idx)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[43], line 7
#       4 for task in tasks.items:
#       5     finished.add(task.data["query"])
# ----> 7 tasks = await tasks.get_next()
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\label_studio_sdk\tasks\client_ext.py:20, in AsyncTasksClientExt.list(self, **kwargs)
#      17 async def list(self, **kwargs):
#      18     # use `fields: all` by default and return the full data
#      19     kwargs['fields'] = kwargs.get('fields', 'all')
# ---> 20     return await AsyncPagerExt.from_async_pager(await super().list(**kwargs))
#
# File c:\Users\20mah\anaconda3\envs\rl\Lib\site-packages\label_studio_sdk\tasks\client.py:1123, in AsyncTasksClient.list(self, fields, include, only_annotated, page, page_size, project, query, resolve_uri, review, selected_items, view, request_options)
#    1121 except JSONDecodeError:
#    1122     raise ApiError(status_code=_response.status_code, body=_response.text)
# -> 1123 raise ApiError(status_code=_response.status_code, body=_response_json)
#
# ApiError: status_code: 404, body: {'id': '4f1b4115-8ace-4a70-94af-726f581e5097', 'status_code': 404, 'version': '1.21.0', 'detail': 'Invalid page.', 'exc_info': None}

# %%
queries = [q for q in queries_df.to_dict("records") if q["query"] not in finished]


sem = asyncio.Semaphore(1)  # concurrency control
async with aiohttp.ClientSession() as session:
    # Iterate asynchronously
    for coro in tqdm.asyncio.tqdm.as_completed(
        [create_task_from_query(session, t, sem) for t in queries],
        unit="queries",
    ):
        try:
            result = await coro

        except Exception as e:
            print("❌ Error:", e)
# Out:
# 100%|██████████| 4994/4994 [34:02<00:00,  2.45queries/s]

# %%
query_row = queries[0]
query_row
# Out:
# {'query': 'امداد خودرو رنو', 'source': 'keywords-04-tir-random.txt'}

# %%
query_row = {"query": "ssd سریع"}

# %%
async with aiohttp.ClientSession() as session:
    options = await fetch_similar(
        session,
        query_row["query"],
        top_k=SAMPLES_PER_QUERY,
    )

# %%
options
# Out:
# [{'keyword': 'بهتر شدن سرعت ssd', 'similarity': 0.8863002},
#  {'keyword': 'پایین آمدن سرعت ssd', 'similarity': 0.82714355},
#  {'keyword': 'ssd samsung', 'similarity': 0.8130125},
#  {'keyword': 'as ssd', 'similarity': 0.8045932},
#  {'keyword': 'بهترین هارد ssd', 'similarity': 0.7971209},
#  {'keyword': 'tweak ssd', 'similarity': 0.777882},
#  {'keyword': 'fastdisk', 'similarity': 0.7752943},
#  {'keyword': 'ssd msata', 'similarity': 0.7731728},
#  {'keyword': 'msata ssd 512gb', 'similarity': 0.769642},
#  {'keyword': 'is internal ssd faster than external', 'similarity': 0.7685696}]

# %%
len(options)
# Out:
# 10

# %%
# async def create_task(
#     query_row: dict[str, str],
#     options: list[dict[str, str]],
# ):
#     return await ls_client.tasks.create(
#         data={
#             "options": [
#                 {"value": item["keyword"], "score": item["similarity"]}
#                 for item in options
#             ],
#             **query_row,
#         },
#         project=project.id,
#     )


task = await create_task(query_row, options)
task
# Out:
# LseTask(agreement=None, agreement_selected=None, annotations=None, annotations_ids=None, annotations_results=None, annotators=None, annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 12, 15, 22, 59, 789207, tzinfo=datetime.timezone.utc), data={'options': [{'value': 'بهتر شدن سرعت ssd', 'score': 0.8863002, 'hint': 'translation I guess'}, {'value': 'پایین آمدن سرعت ssd', 'score': 0.82714355, 'hint': 'translation I guess'}, {'value': 'ssd samsung', 'score': 0.8130125, 'hint': 'translation I guess'}, {'value': 'as ssd', 'score': 0.8045932, 'hint': 'translation I guess'}, {'value': 'بهترین هارد ssd', 'score': 0.7971209, 'hint': 'translation I guess'}, {'value': 'tweak ssd', 'score': 0.777882, 'hint': 'translation I guess'}, {'value': 'fastdisk', 'score': 0.7752943, 'hint': 'translation I guess'}, {'value': 'ssd msata', 'score': 0.7731728, 'hint': 'translation I guess'}, {'value': 'msata ssd 512gb', 'score': 0.769642, 'hint': 'translation I guess'}, {'value': 'is internal ssd faster than external', 'score': 0.7685696, 'hint': 'translation I guess'}], 'query': 'ssd سریع'}, draft_exists=None, drafts=None, file_upload=None, ground_truth=None, id=7036, inner_id=6014, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=None, predictions_model_versions=None, predictions_results=None, predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=0, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 12, 15, 22, 59, 789235, tzinfo=datetime.timezone.utc), updated_by=None)

# %%
task.data
# Out:
# {'options': [{'value': 'لباس مجلسی پسرانه', 'score': 0.9361354},
#   {'value': 'لباس پسرانه مجلسی', 'score': 0.92647344},
#   {'value': 'خرید لباس مجلسی بچه گانه دخترانه شیک', 'score': 0.848766},
#   {'value': 'لباس های مجلسی شیک', 'score': 0.8246183},
#   {'value': 'لباسهای مجلسی', 'score': 0.8160416},
#   {'value': 'نوجوان لباس مجلسی شیک دخترانه', 'score': 0.81401956},
#   {'value': 'لباس مجلسی دخترانه شیک', 'score': 0.8134425},
#   {'value': 'لباس مجلسی', 'score': 0.806944},
#   {'value': 'لباس مجلسی دخترانه نوجوان', 'score': 0.8037823},
#   {'value': 'لباس مجلس', 'score': 0.80318695}],
#  'query': 'خرید لباس مجلسی پسرانه',
#  'source': 'keywords-04-tir-random.txt'}

# %%
from label_studio_sdk.label_interface.objects import PredictionValue
import tqdm.auto as tqdm
import json

PROJECT_ID = 1

project = ls_client.projects.get(id=PROJECT_ID)

# Get the parsed labeling interface to build valid prediction payloads
li = project.get_label_interface()
task_filter = {
    "filters": {
        "conjunction": "and",
        "items": [
            {
                "filter": "filter:tasks:total_annotations",
                "operator": "equal",
                "value": 0,
                "type": "Number",
            },
            {
                "filter": "filter:tasks:cancelled_annotations",
                "operator": "equal",
                "value": 0,
                "type": "Number",
            },
        ],
    }
}

# Iterate tasks and attach predictions
for task in tqdm.tqdm(
    ls_client.tasks.list(
        project=project.id,
        query=json.dumps(task_filter),
    )
):
    task_data = task.data
    new_predictions = ...

    predicted_label = li.get_control("rel").label(new_predictions)
    score = None

    if task.predictions:
        prev_predictions = set(task.predictions[0].result[0]["value"]["choices"])

        common = prev_predictions.intersection(new_predictions)
        union = prev_predictions.union(new_predictions)

        score = len(common) / len(union)

    prediction = PredictionValue(
        model_version="mahdi",
        score=score,
        result=[predicted_label],
    )

    ls_client.predictions.create(task=task.id, **prediction.model_dump())
# Out:
# 0it [00:00, ?it/s]

# %%
ls_client.tasks.create(data=)

# %%
ls_client.tasks.list(
    project=project.id,
    query=json.dumps(task_filter),
)
# Out:
# SyncPagerExt(has_next=True, items=[LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747569, tzinfo=datetime.timezone.utc), data={'query': 'ضبط صوت سامسونگ', 'site_count': 24, 'options': [{'value': 'ضبط صوت سامسونگ', 'score': 0.99999994}, {'value': 'وصل كردن گوشي به تلويزيون سامسونگ', 'score': 0.8253835}, {'value': 'باز كردن رمز گوشي سامسونگ', 'score': 0.8237331}, {'value': 'وصل كردن گوشي سامسونگ به تلویزیون', 'score': 0.8068063}, {'value': 'پخش کننده موسیقی سامسونگ', 'score': 0.77631205}, {'value': 'voice focus samsung', 'score': 0.77151215}, {'value': 'نصب شنود روی گوشی', 'score': 0.7510103}, {'value': 'call ضبط مکالمه دو طرفه گوشی سامسونگ', 'score': 0.7452122}, {'value': 'قيمت گوشي سامسونگ', 'score': 0.7358978}, {'value': 'دانلود برنامه موسیقی سامسونگ', 'score': 0.72821105}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=17, inner_id=17, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974455, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['ضبط صوت سامسونگ', 'پخش کننده موسیقی سامسونگ', 'دانلود برنامه موسیقی سامسونگ']}}], score=None, task=17, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974463, tzinfo=datetime.timezone.utc), id=2066, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0), LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 296352, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='mahdi', project=1, result=[{'id': '32e3f974-b620-49fa-9509-3146ca886277', 'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['وصل كردن گوشي سامسونگ به تلویزیون', 'ضبط صوت سامسونگ']}}], score=0.0, task=17, updated_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 296385, tzinfo=datetime.timezone.utc), id=3074, created_ago='22\xa0minutes', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='mahdi,undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0636\\u0628\\u0637 \\u0635\\u0648\\u062a \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af, \\u067e\\u062e\\u0634 \\u06a9\\u0646\\u0646\\u062f\\u0647 \\u0645\\u0648\\u0633\\u06cc\\u0642\\u06cc \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af, \\u062f\\u0627\\u0646\\u0644\\u0648\\u062f \\u0628\\u0631\\u0646\\u0627\\u0645\\u0647 \\u0645\\u0648\\u0633\\u06cc\\u0642\\u06cc \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af]}}] [{id: 32e3f974-b620-49fa-9509-3146ca88627', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=2, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 284312, tzinfo=datetime.timezone.utc), updated_by=[{'user_id': 1}]), LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747637, tzinfo=datetime.timezone.utc), data={'query': 'متن تشکر از عشقم بابت کادو', 'site_count': 21, 'options': [{'value': 'بهترین کادو برای عشقم', 'score': 0.7656926}, {'value': 'متن قدردانی', 'score': 0.713515}, {'value': 'متن تشکر', 'scor ...

# %%
list(_47)
# Out:
# [LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747569, tzinfo=datetime.timezone.utc), data={'query': 'ضبط صوت سامسونگ', 'site_count': 24, 'options': [{'value': 'ضبط صوت سامسونگ', 'score': 0.99999994}, {'value': 'وصل كردن گوشي به تلويزيون سامسونگ', 'score': 0.8253835}, {'value': 'باز كردن رمز گوشي سامسونگ', 'score': 0.8237331}, {'value': 'وصل كردن گوشي سامسونگ به تلویزیون', 'score': 0.8068063}, {'value': 'پخش کننده موسیقی سامسونگ', 'score': 0.77631205}, {'value': 'voice focus samsung', 'score': 0.77151215}, {'value': 'نصب شنود روی گوشی', 'score': 0.7510103}, {'value': 'call ضبط مکالمه دو طرفه گوشی سامسونگ', 'score': 0.7452122}, {'value': 'قيمت گوشي سامسونگ', 'score': 0.7358978}, {'value': 'دانلود برنامه موسیقی سامسونگ', 'score': 0.72821105}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=17, inner_id=17, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974455, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['ضبط صوت سامسونگ', 'پخش کننده موسیقی سامسونگ', 'دانلود برنامه موسیقی سامسونگ']}}], score=None, task=17, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974463, tzinfo=datetime.timezone.utc), id=2066, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0), LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 296352, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='mahdi', project=1, result=[{'id': '32e3f974-b620-49fa-9509-3146ca886277', 'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['وصل كردن گوشي سامسونگ به تلویزیون', 'ضبط صوت سامسونگ']}}], score=0.0, task=17, updated_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 296385, tzinfo=datetime.timezone.utc), id=3074, created_ago='22\xa0minutes', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='mahdi,undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0636\\u0628\\u0637 \\u0635\\u0648\\u062a \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af, \\u067e\\u062e\\u0634 \\u06a9\\u0646\\u0646\\u062f\\u0647 \\u0645\\u0648\\u0633\\u06cc\\u0642\\u06cc \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af, \\u062f\\u0627\\u0646\\u0644\\u0648\\u062f \\u0628\\u0631\\u0646\\u0627\\u0645\\u0647 \\u0645\\u0648\\u0633\\u06cc\\u0642\\u06cc \\u0633\\u0627\\u0645\\u0633\\u0648\\u0646\\u06af]}}] [{id: 32e3f974-b620-49fa-9509-3146ca88627', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=2, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 12, 6, 44, 49, 284312, tzinfo=datetime.timezone.utc), updated_by=[{'user_id': 1}]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747637, tzinfo=datetime.timezone.utc), data={'query': 'متن تشکر از عشقم بابت کادو', 'site_count': 21, 'options': [{'value': 'بهترین کادو برای عشقم', 'score': 0.7656926}, {'value': 'متن قدردانی', 'score': 0.713515}, {'value': 'متن تشکر', 'score': 0.7098897}, {'value': 'عاشقانه تشکر از همسر', 'score': 0.6967017}, {'value': 'رسالة شكر لصديقتي على الهديه', 'score': 0.69243217}, {'value': 'متن ادبی تشکر تسلیت', 'score': 0.68806064}, {'value': 'متن تشکر بابت هدیه گرفتن', 'score': 0.6782702}, {'value': 'پیام تشکر و قدردانی', 'score': 0.6758715}, {'value': 'thank you note', 'score': 0.66580164}, {'value': 'ببخشید عشقم', 'score': 0.6652013}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=18, inner_id=18, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974497, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['متن قدردانی', 'متن تشکر', 'عاشقانه تشکر از همسر', 'متن تشکر بابت هدیه گرفتن', 'پیام تشکر و قدردانی']}}], score=None, task=18, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974505, tzinfo=datetime.timezone.utc), id=2067, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0645\\u062a\\u0646 \\u0642\\u062f\\u0631\\u062f\\u0627\\u0646\\u06cc, \\u0645\\u062a\\u0646 \\u062a\\u0634\\u06a9\\u0631, \\u0639\\u0627\\u0634\\u0642\\u0627\\u0646\\u0647 \\u062a\\u0634\\u06a9\\u0631 \\u0627\\u0632 \\u0647\\u0645\\u0633\\u0631, \\u0645\\u062a\\u0646 \\u062a\\u0634\\u06a9\\u0631 \\u0628\\u0627\\u0628\\u062a \\u0647\\u062f\\u06cc\\u0647 \\u06af\\u0631\\u0641\\u062a\\u0646, \\u067e\\u06cc\\u0627\\u0645 \\u062a\\u0634\\u06a9\\u0631 \\u0648 \\u0642\\u062f\\u', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747646, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747706, tzinfo=datetime.timezone.utc), data={'query': 'روز جهانی مرد مبارک', 'site_count': 24, 'options': [{'value': 'متن روز مرد مبارک', 'score': 0.8763591}, {'value': 'تبریک روز مرد', 'score': 0.86297333}, {'value': 'متن کوتاه تبریک روز مرد', 'score': 0.84165674}, {'value': 'پیام تبریک روز مرد', 'score': 0.8296155}, {'value': 'متن تبریک روز مرد رسمی', 'score': 0.8112149}, {'value': 'روزت مبارک مرد من', 'score': 0.801834}, {'value': 'متن روز مرد رسمی', 'score': 0.7626233}, {'value': 'روز مرد مبارک رفیق', 'score': 0.7593696}, {'value': 'پسرم روز مرد مبارک', 'score': 0.7589529}, {'value': 'متن زیبا برای روز مرد', 'score': 0.7525294}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=19, inner_id=19, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974553, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['تبریک روز مرد', 'متن کوتاه تبریک روز مرد', 'پیام تبریک روز مرد', 'متن تبریک روز مرد رسمی', 'متن روز مرد رسمی', 'متن زیبا برای روز مرد']}}], score=None, task=19, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974564, tzinfo=datetime.timezone.utc), id=2068, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0631\\u0648\\u0632 \\u0645\\u0631\\u062f, \\u0645\\u062a\\u0646 \\u06a9\\u0648\\u062a\\u0627\\u0647 \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0631\\u0648\\u0632 \\u0645\\u0631\\u062f, \\u067e\\u06cc\\u0627\\u0645 \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0631\\u0648\\u0632 \\u0645\\u0631\\u062f, \\u0645\\u062a\\u0646 \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0631\\u0648\\u0632 \\u0645\\u0631\\u062f \\u0631\\u0633\\u0645\\u06cc, \\u0645\\u062a\\', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747715, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747771, tzinfo=datetime.timezone.utc), data={'query': 'بایرن مقابل شالکه', 'site_count': 23, 'options': [{'value': 'بایرن مقابل شالکه', 'score': 1.0000001}, {'value': 'match bayern', 'score': 0.802732}, {'value': 'le match de bayern', 'score': 0.7896156}, {'value': 'le match du bayern', 'score': 0.78193074}, {'value': 'bayern dernier match', 'score': 0.77632785}, {'value': 'bayern münih maçı', 'score': 0.77619916}, {'value': 'لورکوزن مقابل بایرن', 'score': 0.768569}, {'value': 'le match de bayern munich', 'score': 0.7596896}, {'value': 'bayern - frankfurt', 'score': 0.75738865}, {'value': 'bayern munich', 'score': 0.7411658}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=20, inner_id=20, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974597, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['بایرن مقابل شالکه', 'bayern münih maçı', 'بایرن - فرانکفورت', 'بایرن مونیخ']}}], score=None, task=20, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974606, tzinfo=datetime.timezone.utc), id=2069, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0628\\u0627\\u06cc\\u0631\\u0646 \\u0645\\u0642\\u0627\\u0628\\u0644 \\u0634\\u0627\\u0644\\u06a9\\u0647, bayern m\\u00fcnih ma\\u00e7\\u0131, \\u0628\\u0627\\u06cc\\u0631\\u0646 - \\u0641\\u0631\\u0627\\u0646\\u06a9\\u0641\\u0648\\u0631\\u062a, \\u0628\\u0627\\u06cc\\u0631\\u0646 \\u0645\\u0648\\u0646\\u06cc\\u062e]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747779, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747876, tzinfo=datetime.timezone.utc), data={'query': 'عکس پسر فیک', 'site_count': 28, 'options': [{'value': 'عکس فیک پسرونه طبیعی', 'score': 0.81554604}, {'value': 'عکس شناسنامه فیک', 'score': 0.78727853}, {'value': 'عکس فیک', 'score': 0.7847187}, {'value': 'عکس پسرانه پروفایل', 'score': 0.7820238}, {'value': 'عکس پروفایل فیک', 'score': 0.77426684}, {'value': 'عکس نود فیک', 'score': 0.7646444}, {'value': 'عکس پروفایل پسرونه', 'score': 0.7626131}, {'value': 'عکس فاک', 'score': 0.7616471}, {'value': 'عکس پسرانه برای پروفایل', 'score': 0.76079434}, {'value': 'عکس جذاب پسرانه', 'score': 0.75640374}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=21, inner_id=21, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974641, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['عکس فیک پسرونه طبیعی', 'عکس فیک', 'عکس پروفایل فیک', 'عکس پروفایل پسرونه', 'عکس پسرانه برای پروفایل', 'عکس جذاب پسرانه']}}], score=None, task=21, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974649, tzinfo=datetime.timezone.utc), id=2070, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0639\\u06a9\\u0633 \\u0641\\u06cc\\u06a9 \\u067e\\u0633\\u0631\\u0648\\u0646\\u0647 \\u0637\\u0628\\u06cc\\u0639\\u06cc, \\u0639\\u06a9\\u0633 \\u0641\\u06cc\\u06a9, \\u0639\\u06a9\\u0633 \\u067e\\u0631\\u0648\\u0641\\u0627\\u06cc\\u0644 \\u0641\\u06cc\\u06a9, \\u0639\\u06a9\\u0633 \\u067e\\u0631\\u0648\\u0641\\u0627\\u06cc\\u0644 \\u067e\\u0633\\u0631\\u0648\\u0646\\u0647, \\u0639\\u06a9\\u0633 \\u067e\\u0633\\u0631\\u0627\\u0646\\u0647 \\u0628\\u0631\\u0627\\u06cc \\u0', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747889, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747956, tzinfo=datetime.timezone.utc), data={'query': 'پیچ اشتباه ۶', 'site_count': 28, 'options': [{'value': 'پیچ اشتباه ۶ بدون سانسور', 'score': 0.8604887}, {'value': 'فیلم پیچ اشتباه ۳', 'score': 0.69536495}, {'value': 'داستان فیلم پیچ اشتباه ۸', 'score': 0.68431664}, {'value': '٦', 'score': 0.6815007}, {'value': 'عدد شش', 'score': 0.67260617}, {'value': 'سوالات ریاضی ششم', 'score': 0.6709233}, {'value': 'ششم', 'score': 0.67078036}, {'value': 'ضشش شش', 'score': 0.65630305}, {'value': 'نمونه سوالات ریاضی ششم', 'score': 0.64796746}, {'value': 'ریاضی هشتم صفحه ۶', 'score': 0.6393501}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=22, inner_id=22, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974695, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['پیچ اشتباه ۶ بدون سانسور', 'فیلم پیچ اشتباه ۳', 'داستان فیلم پیچ اشتباه ۸']}}], score=None, task=22, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974704, tzinfo=datetime.timezone.utc), id=2071, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u067e\\u06cc\\u0686 \\u0627\\u0634\\u062a\\u0628\\u0627\\u0647 \\u06f6 \\u0628\\u062f\\u0648\\u0646 \\u0633\\u0627\\u0646\\u0633\\u0648\\u0631, \\u0641\\u06cc\\u0644\\u0645 \\u067e\\u06cc\\u0686 \\u0627\\u0634\\u062a\\u0628\\u0627\\u0647 \\u06f3, \\u062f\\u0627\\u0633\\u062a\\u0627\\u0646 \\u0641\\u06cc\\u0644\\u0645 \\u067e\\u06cc\\u0686 \\u0627\\u0634\\u062a\\u0628\\u0627\\u0647 \\u06f8]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 747981, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748042, tzinfo=datetime.timezone.utc), data={'query': 'انواع مزه دار كردن جوجه كباب', 'site_count': 23, 'options': [{'value': 'طرز تهیه جوجه کباب', 'score': 0.77425504}, {'value': 'جوجه\u200cکباب', 'score': 0.76388407}, {'value': 'کباب جوجه', 'score': 0.7578614}, {'value': 'جوجه کبک', 'score': 0.70081306}, {'value': 'جوجه کباب زعفرانی', 'score': 0.6934772}, {'value': 'طرز تهیه جوجه کباب تابه ای آبدار', 'score': 0.69276184}, {'value': 'جوجه مرغ شاخدار', 'score': 0.68826556}, {'value': 'طرز پخت اکبر جوجه', 'score': 0.6718241}, {'value': 'تهیه اکبر جوجه', 'score': 0.67179483}, {'value': 'کاردستی جوجه آسان', 'score': 0.66923416}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=23, inner_id=23, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974738, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['طرز تهیه جوجه کباب', 'جوجه\u200cکباب', 'کباب جوجه', 'جوجه کباب زعفرانی', 'طرز تهیه جوجه کباب تابه ای آبدار', 'طرز پخت اکبر جوجه', 'تهیه اکبر جوجه']}}], score=None, task=23, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974746, tzinfo=datetime.timezone.utc), id=2072, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0637\\u0631\\u0632 \\u062a\\u0647\\u06cc\\u0647 \\u062c\\u0648\\u062c\\u0647 \\u06a9\\u0628\\u0627\\u0628, \\u062c\\u0648\\u062c\\u0647\\u200c\\u06a9\\u0628\\u0627\\u0628, \\u06a9\\u0628\\u0627\\u0628 \\u062c\\u0648\\u062c\\u0647, \\u062c\\u0648\\u062c\\u0647 \\u06a9\\u0628\\u0627\\u0628 \\u0632\\u0639\\u0641\\u0631\\u0627\\u0646\\u06cc, \\u0637\\u0631\\u0632 \\u062a\\u0647\\u06cc\\u0647 \\u062c\\u0648\\u062c\\u0647 \\u06a9\\u0628\\u0627\\u0628 \\u062a\\u0627\\u0628\\u06', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748051, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748139, tzinfo=datetime.timezone.utc), data={'query': 'علائم سکته مغزی', 'site_count': 31, 'options': [{'value': 'ایا سکته مغزی خوب میشود', 'score': 0.88975084}, {'value': 'سکته مغزی خفیف خطرناک است', 'score': 0.82392764}, {'value': 'سکته مغزی به انگلیسی', 'score': 0.82100236}, {'value': 'استفراغ بعد از سکته مغزی نشانه چیست', 'score': 0.79271114}, {'value': 'سکته مغزی ابرو گوندش', 'score': 0.7708261}, {'value': 'علائم سکته خفیف', 'score': 0.75382143}, {'value': 'مراقبت از بیمار سکته مغزی در منزل', 'score': 0.7186684}, {'value': 'علائم خونریزی مغزی', 'score': 0.6664525}, {'value': 'علائم اولیه تومور مغزی', 'score': 0.652638}, {'value': 'سرطان مغزی', 'score': 0.60788333}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=24, inner_id=24, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974777, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['علائم سکته خفیف', 'استفراغ بعد از سکته مغزی نشانه چیست', 'علائم خونریزی مغزی']}}], score=None, task=24, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974785, tzinfo=datetime.timezone.utc), id=2073, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0639\\u0644\\u0627\\u0626\\u0645 \\u0633\\u06a9\\u062a\\u0647 \\u062e\\u0641\\u06cc\\u0641, \\u0627\\u0633\\u062a\\u0641\\u0631\\u0627\\u063a \\u0628\\u0639\\u062f \\u0627\\u0632 \\u0633\\u06a9\\u062a\\u0647 \\u0645\\u063a\\u0632\\u06cc \\u0646\\u0634\\u0627\\u0646\\u0647 \\u0686\\u06cc\\u0633\\u062a, \\u0639\\u0644\\u0627\\u0626\\u0645 \\u062e\\u0648\\u0646\\u0631\\u06cc\\u0632\\u06cc \\u0645\\u063a\\u0632\\u06cc]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748149, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748316, tzinfo=datetime.timezone.utc), data={'query': 'سینما اطلس', 'site_count': 37, 'options': [{'value': 'سینمای', 'score': 0.7143769}, {'value': 'سینما ملت', 'score': 0.7098628}, {'value': 'سینما', 'score': 0.7041594}, {'value': 'سینما ونوس', 'score': 0.67737615}, {'value': 'cinematheque', 'score': 0.6765568}, {'value': 'سينما وبس', 'score': 0.6722269}, {'value': 'فيلم سينمائي', 'score': 0.65740585}, {'value': 'filamu', 'score': 0.65674525}, {'value': 'فیلم آلیس در سرزمین عجایب', 'score': 0.64950264}, {'value': 'فیلم های الکسیس', 'score': 0.6475276}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=26, inner_id=26, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974926, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['سینمای', 'سینما ملت', 'سینما', 'سینما ونوس', 'سينما وبس']}}], score=None, task=26, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974948, tzinfo=datetime.timezone.utc), id=2075, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0633\\u06cc\\u0646\\u0645\\u0627\\u06cc, \\u0633\\u06cc\\u0646\\u0645\\u0627 \\u0645\\u0644\\u062a, \\u0633\\u06cc\\u0646\\u0645\\u0627, \\u0633\\u06cc\\u0646\\u0645\\u0627 \\u0648\\u0646\\u0648\\u0633, \\u0633\\u064a\\u0646\\u0645\\u0627 \\u0648\\u0628\\u0633]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748325, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748384, tzinfo=datetime.timezone.utc), data={'query': 'تبریک سال نو ۱۴۰۲', 'site_count': 48, 'options': [{'value': 'پیام تبریک سال نو ۱۴۰۲', 'score': 0.9831993}, {'value': 'پیام تبریک سال نو ۱۴۰۳', 'score': 0.9034106}, {'value': 'تبریک عید نوروز ۱۴۰۲', 'score': 0.8988187}, {'value': 'پیام تبریک عید نوروز ۱۴۰۲', 'score': 0.89722043}, {'value': 'تبریک رسمی سال نو', 'score': 0.8795519}, {'value': 'تبریک سال نو رسمی', 'score': 0.8794532}, {'value': 'متن کوتاه تبریک سال نو', 'score': 0.8491123}, {'value': 'متن برای تبریک سال نو', 'score': 0.84443355}, {'value': 'عکس تبریک سال نو ۱۴۰۳', 'score': 0.8433188}, {'value': 'تبریک نوروز ۱۴۰۳', 'score': 0.84050864}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=27, inner_id=27, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974989, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['پیام تبریک سال نو ۱۴۰۲', 'تبریک عید نوروز ۱۴۰۲', 'پیام تبریک عید نوروز ۱۴۰۲', 'تبریک رسمی سال نو', 'تبریک سال نو رسمی', 'متن کوتاه تبریک سال نو', 'متن برای تبریک سال نو']}}], score=None, task=27, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 974998, tzinfo=datetime.timezone.utc), id=2076, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u067e\\u06cc\\u0627\\u0645 \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0633\\u0627\\u0644 \\u0646\\u0648 \\u06f1\\u06f4\\u06f0\\u06f2, \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0639\\u06cc\\u062f \\u0646\\u0648\\u0631\\u0648\\u0632 \\u06f1\\u06f4\\u06f0\\u06f2, \\u067e\\u06cc\\u0627\\u0645 \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0639\\u06cc\\u062f \\u0646\\u0648\\u0631\\u0648\\u0632 \\u06f1\\u06f4\\u06f0\\u06f2, \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0631\\u0633\\u0645\\u06cc \\u063', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748392, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748449, tzinfo=datetime.timezone.utc), data={'query': 'قیمت پراید صفر ۱۴۰۱', 'site_count': 36, 'options': [{'value': 'قیمت پراید صفر', 'score': 0.9564148}, {'value': 'قیمت پراید ۱۳۱ صفر امروز', 'score': 0.8944771}, {'value': 'پراید صفر', 'score': 0.87765694}, {'value': 'قیمت پراید ۱۳۱', 'score': 0.87353396}, {'value': 'قیمت پراید در ایران', 'score': 0.8567107}, {'value': 'قیمت روز پراید', 'score': 0.8500907}, {'value': 'پراید ۱۵۱', 'score': 0.79226744}, {'value': 'فروش پراید', 'score': 0.7880915}, {'value': 'پراید۱۱۱', 'score': 0.7732927}, {'value': 'پراید۱۳۱', 'score': 0.7710093}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=28, inner_id=28, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975035, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['قیمت پراید صفر', 'قیمت پراید ۱۳۱ صفر امروز', 'پراید صفر', 'قیمت پراید ۱۳۱', 'قیمت پراید در ایران', 'قیمت روز پراید', 'پراید۱۱۱', 'پراید۱۳۱']}}], score=None, task=28, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975043, tzinfo=datetime.timezone.utc), id=2077, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0642\\u06cc\\u0645\\u062a \\u067e\\u0631\\u0627\\u06cc\\u062f \\u0635\\u0641\\u0631, \\u0642\\u06cc\\u0645\\u062a \\u067e\\u0631\\u0627\\u06cc\\u062f \\u06f1\\u06f3\\u06f1 \\u0635\\u0641\\u0631 \\u0627\\u0645\\u0631\\u0648\\u0632, \\u067e\\u0631\\u0627\\u06cc\\u062f \\u0635\\u0641\\u0631, \\u0642\\u06cc\\u0645\\u062a \\u067e\\u0631\\u0627\\u06cc\\u062f \\u06f1\\u06f3\\u06f1, \\u0642\\u06cc\\u0645\\u062a \\u067e\\u0631\\u0627\\u06cc\\u062f \\u062f\\u0631 \\u0627\\u06cc\\u', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748466, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748533, tzinfo=datetime.timezone.utc), data={'query': 'ارش مجیدی', 'site_count': 28, 'options': [{'value': 'مجید مجیدی', 'score': 0.9153747}, {'value': 'مجید معظمی', 'score': 0.72386646}, {'value': 'مجید علیپور', 'score': 0.72081697}, {'value': 'مجید قاسمی', 'score': 0.7081909}, {'value': 'مجیدبهرامی', 'score': 0.7068377}, {'value': 'مجیدیه کوی', 'score': 0.70634454}, {'value': 'مجید یوسفی', 'score': 0.6890616}, {'value': 'فرهاد مهراد', 'score': 0.68721175}, {'value': 'فرهاد جم', 'score': 0.6617496}, {'value': 'مجید اوجی', 'score': 0.65614974}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=29, inner_id=29, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975078, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['مجید مجیدی', 'مجید معظمی', 'مجید علیپور', 'مجید قاسمی', 'مجید یوسفی', 'مجید اوجی']}}], score=None, task=29, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975086, tzinfo=datetime.timezone.utc), id=2078, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0645\\u062c\\u06cc\\u062f \\u0645\\u062c\\u06cc\\u062f\\u06cc, \\u0645\\u062c\\u06cc\\u062f \\u0645\\u0639\\u0638\\u0645\\u06cc, \\u0645\\u062c\\u06cc\\u062f \\u0639\\u0644\\u06cc\\u067e\\u0648\\u0631, \\u0645\\u062c\\u06cc\\u062f \\u0642\\u0627\\u0633\\u0645\\u06cc, \\u0645\\u062c\\u06cc\\u062f \\u06cc\\u0648\\u0633\\u0641\\u06cc, \\u0645\\u062c\\u06cc\\u062f \\u0627\\u0648\\u062c\\u06cc]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748542, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748601, tzinfo=datetime.timezone.utc), data={'query': 'روستای حلیمه جان', 'site_count': 23, 'options': [{'value': 'روستا', 'score': 0.65523523}, {'value': 'روستای هرانده', 'score': 0.6275486}, {'value': 'روستای خمده', 'score': 0.6236489}, {'value': 'روستای امامه', 'score': 0.6219644}, {'value': 'روستای پالنگان', 'score': 0.6162449}, {'value': 'عکس روستا', 'score': 0.60664964}, {'value': 'عمو جان', 'score': 0.60198283}, {'value': 'روستای لاویج', 'score': 0.59346914}, {'value': 'قرية الريم', 'score': 0.59319776}, {'value': 'فیلم عمو جانی', 'score': 0.58051544}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=30, inner_id=30, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975118, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['روستا', 'عکس روستا']}}], score=None, task=30, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975126, tzinfo=datetime.timezone.utc), id=2079, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0631\\u0648\\u0633\\u062a\\u0627, \\u0639\\u06a9\\u0633 \\u0631\\u0648\\u0633\\u062a\\u0627]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748617, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748682, tzinfo=datetime.timezone.utc), data={'query': 'نام مادر سعدی', 'site_count': 30, 'options': [{'value': 'سعدی کیست کوتاه', 'score': 0.80445516}, {'value': 'حکایت سعدی', 'score': 0.75918186}, {'value': 'حکایات سعدی', 'score': 0.752885}, {'value': 'شعر معروف سعدی', 'score': 0.7503247}, {'value': 'کتاب سعدی', 'score': 0.7362654}, {'value': 'مهمترین آثار سعدی', 'score': 0.73381174}, {'value': 'شعر های سعدی', 'score': 0.7241091}, {'value': 'سعدی شیرازی', 'score': 0.7028922}, {'value': 'بهترین شعر سعدی', 'score': 0.7006316}, {'value': 'گلچین اشعار سعدی', 'score': 0.6961543}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=31, inner_id=31, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975159, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['سعدی کیست کوتاه', 'سعدی شیرازی', 'کتاب سعدی', 'مهمترین آثار سعدی']}}], score=None, task=31, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975168, tzinfo=datetime.timezone.utc), id=2080, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0633\\u0639\\u062f\\u06cc \\u06a9\\u06cc\\u0633\\u062a \\u06a9\\u0648\\u062a\\u0627\\u0647, \\u0633\\u0639\\u062f\\u06cc \\u0634\\u06cc\\u0631\\u0627\\u0632\\u06cc, \\u06a9\\u062a\\u0627\\u0628 \\u0633\\u0639\\u062f\\u06cc, \\u0645\\u0647\\u0645\\u062a\\u0631\\u06cc\\u0646 \\u0622\\u062b\\u0627\\u0631 \\u0633\\u0639\\u062f\\u06cc]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748704, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748764, tzinfo=datetime.timezone.utc), data={'query': 'اسم نام کشورها', 'site_count': 26, 'options': [{'value': 'اسم کشور ها', 'score': 0.95927095}, {'value': 'نام کشورهای جهان روی نقشه', 'score': 0.82432747}, {'value': 'পৃথিবীর সকল দেশের নাম', 'score': 0.8218915}, {'value': 'الدول', 'score': 0.81317043}, {'value': 'страны по территории', 'score': 0.81311744}, {'value': 'mga bansa sa buong mundo', 'score': 0.79615605}, {'value': 'أشهر دول العالم', 'score': 0.794726}, {'value': 'کود کشورها', 'score': 0.7871868}, {'value': 'ilang bansa sa buong mundo', 'score': 0.7790115}, {'value': 'کد های کشورها', 'score': 0.7668536}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=32, inner_id=32, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975239, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['اسم کشور ها', 'نام کشورهای جهان روی نقشه', 'پرتغال کشورهای نام', 'کد های کشورها']}}], score=None, task=32, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975247, tzinfo=datetime.timezone.utc), id=2081, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0627\\u0633\\u0645 \\u06a9\\u0634\\u0648\\u0631 \\u0647\\u0627, \\u0646\\u0627\\u0645 \\u06a9\\u0634\\u0648\\u0631\\u0647\\u0627\\u06cc \\u062c\\u0647\\u0627\\u0646 \\u0631\\u0648\\u06cc \\u0646\\u0642\\u0634\\u0647, \\u067e\\u0631\\u062a\\u063a\\u0627\\u0644 \\u06a9\\u0634\\u0648\\u0631\\u0647\\u0627\\u06cc \\u0646\\u0627\\u0645, \\u06a9\\u062f \\u0647\\u0627\\u06cc \\u06a9\\u0634\\u0648\\u0631\\u0647\\u0627]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748784, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748903, tzinfo=datetime.timezone.utc), data={'query': 'سیمای بارلاس', 'site_count': 24, 'options': [{'value': 'سيماى بارلاس', 'score': 0.81186247}, {'value': 'ملیسا باررا', 'score': 0.6616926}, {'value': 'باربوسا', 'score': 0.65934443}, {'value': 'باریستا', 'score': 0.6558102}, {'value': 'باروس', 'score': 0.6502675}, {'value': 'بابليس', 'score': 0.6238168}, {'value': 'فامیلی باکلاس', 'score': 0.6209064}, {'value': 'barcl', 'score': 0.62043536}, {'value': 'پا لیس', 'score': 0.62033623}, {'value': 'بارسا', 'score': 0.61957246}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=33, inner_id=33, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975293, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['سيماى بارلاس']}}], score=None, task=33, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975301, tzinfo=datetime.timezone.utc), id=2082, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0633\\u064a\\u0645\\u0627\\u0649 \\u0628\\u0627\\u0631\\u0644\\u0627\\u0633]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748917, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748986, tzinfo=datetime.timezone.utc), data={'query': 'شاهین فتحی', 'site_count': 30, 'options': [{'value': 'شاهین آفریدی', 'score': 0.8369669}, {'value': 'سهیل شاهین', 'score': 0.76703715}, {'value': 'شاهین شکاری', 'score': 0.7586678}, {'value': 'شاهین بنان', 'score': 0.73728895}, {'value': 'شاهین مشکی', 'score': 0.7299703}, {'value': 'کابین شاهین', 'score': 0.712453}, {'value': 'رینگ شاهین', 'score': 0.69793785}, {'value': 'شاهین شاسی بلند', 'score': 0.694536}, {'value': 'عکس شاهین', 'score': 0.6939921}, {'value': 'شاهین اتومات', 'score': 0.6876043}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=34, inner_id=34, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975360, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['شاهین آفریدی', 'سهیل شاهین', 'شاهین شکاری', 'شاهین بنان', 'شاهین مشکی', 'کابین شاهین', 'رینگ شاهین', 'شاهین شاسی بلند', 'عکس شاهین', 'شاهین اتومات']}}], score=None, task=34, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975368, tzinfo=datetime.timezone.utc), id=2083, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0634\\u0627\\u0647\\u06cc\\u0646 \\u0622\\u0641\\u0631\\u06cc\\u062f\\u06cc, \\u0633\\u0647\\u06cc\\u0644 \\u0634\\u0627\\u0647\\u06cc\\u0646, \\u0634\\u0627\\u0647\\u06cc\\u0646 \\u0634\\u06a9\\u0627\\u0631\\u06cc, \\u0634\\u0627\\u0647\\u06cc\\u0646 \\u0628\\u0646\\u0627\\u0646, \\u0634\\u0627\\u0647\\u06cc\\u0646 \\u0645\\u0634\\u06a9\\u06cc, \\u06a9\\u0627\\u0628\\u06cc\\u0646 \\u0634\\u0627\\u0647\\u06cc\\u0646, \\u0631\\u06cc\\u0646\\u06af \\u0634\\u0627\\u064', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 748995, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 749056, tzinfo=datetime.timezone.utc), data={'query': 'علی صادقی', 'site_count': 53, 'options': [{'value': 'همسر علی صادقی', 'score': 0.8410053}, {'value': 'رضا صادقی', 'score': 0.82831764}, {'value': 'آرش صادقی', 'score': 0.7951488}, {'value': 'زهرا صادقی', 'score': 0.7777716}, {'value': 'علی سامره', 'score': 0.76504076}, {'value': 'محمد صادقی بازیگر', 'score': 0.76117194}, {'value': 'علی احمد', 'score': 0.74907166}, {'value': 'صادق شیرازی', 'score': 0.7464963}, {'value': 'علی علی', 'score': 0.743866}, {'value': 'محمد صادقی بی همگان', 'score': 0.7413797}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=35, inner_id=35, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975399, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['همسر علی صادقی', 'محمد صادقی بازیگر', 'محمد صادقی بی همگان']}}], score=None, task=35, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 975407, tzinfo=datetime.timezone.utc), id=2084, created_ago='1\xa0day, 16\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0647\\u0645\\u0633\\u0631 \\u0639\\u0644\\u06cc \\u0635\\u0627\\u062f\\u0642\\u06cc, \\u0645\\u062d\\u0645\\u062f \\u0635\\u0627\\u062f\\u0642\\u06cc \\u0628\\u0627\\u0632\\u06cc\\u06af\\u0631, \\u0645\\u062d\\u0645\\u062f \\u0635\\u0627\\u062f\\u0642\\u06cc \\u0628\\u06cc \\u0647\\u0645\\u06af\\u0627\\u0646]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 749065, tzinfo=datetime.timezone.utc), updated_by=[]),
# ...
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905274, tzinfo=datetime.timezone.utc), data={'query': 'رضامراد صحرایی', 'site_count': 34, 'options': [{'value': 'رضا کرم رضایی', 'score': 0.67834604}, {'value': 'محمد رضا علیمردانی', 'score': 0.66657513}, {'value': 'رضا اسدی', 'score': 0.6630184}, {'value': 'حمیدرضا مرادی', 'score': 0.6595123}, {'value': 'صحرا اسدالهی', 'score': 0.6585438}, {'value': 'امیر رضایی', 'score': 0.65645194}, {'value': 'حسین رضایی', 'score': 0.65119433}, {'value': 'رضا بهرام', 'score': 0.6445444}, {'value': 'رضا', 'score': 0.6303926}, {'value': 'رضابهرام', 'score': 0.6252343}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=1020, inner_id=1020, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 63973, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['رضا', 'رضابهرام']}}], score=None, task=1020, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 63988, tzinfo=datetime.timezone.utc), id=3069, created_ago='1\xa0day, 17\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0631\\u0636\\u0627, \\u0631\\u0636\\u0627\\u0628\\u0647\\u0631\\u0627\\u0645]}}]', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905282, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905346, tzinfo=datetime.timezone.utc), data={'query': 'احمد مسعود در ایران', 'site_count': 32, 'options': [{'value': 'احمد شاه مسعود و ایران', 'score': 0.88429755}, {'value': 'شهید احمد شاه مسعود', 'score': 0.75509405}, {'value': 'عکس احمد مسعود با لباس نظامی', 'score': 0.75405073}, {'value': 'ابن غسان مسعود', 'score': 0.7142025}, {'value': 'احمد شاه مسعود و قاسم سلیمانی', 'score': 0.68126297}, {'value': 'شهید حکیم الله مسعود', 'score': 0.67088324}, {'value': 'بیت الله مسعود', 'score': 0.6617543}, {'value': 'مسعود بارزاني', 'score': 0.65895903}, {'value': 'مسعود جهانی', 'score': 0.6504962}, {'value': 'شعر در وصف احمد شاه مسعود', 'score': 0.63476884}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=1021, inner_id=1021, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64030, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['احمد شاه مسعود و ایران', 'شهید احمد شاه مسعود', 'احمد شاه مسعود و قاسم سلیمانی', 'شعر در وصف احمد شاه مسعود']}}], score=None, task=1021, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64040, tzinfo=datetime.timezone.utc), id=3070, created_ago='1\xa0day, 17\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0627\\u062d\\u0645\\u062f \\u0634\\u0627\\u0647 \\u0645\\u0633\\u0639\\u0648\\u062f \\u0648 \\u0627\\u06cc\\u0631\\u0627\\u0646, \\u0634\\u0647\\u06cc\\u062f \\u0627\\u062d\\u0645\\u062f \\u0634\\u0627\\u0647 \\u0645\\u0633\\u0639\\u0648\\u062f, \\u0627\\u062d\\u0645\\u062f \\u0634\\u0627\\u0647 \\u0645\\u0633\\u0639\\u0648\\u062f \\u0648 \\u0642\\u0627\\u0633\\u0645 \\u0633\\u0644\\u06cc\\u0645\\u0627\\u0646\\u06cc, \\u0634\\u0639\\u0631 \\u062f\\u0631 \\u0648\\u0635\\u06', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905355, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905429, tzinfo=datetime.timezone.utc), data={'query': 'بازیگران یوسف پیامبر', 'site_count': 60, 'options': [{'value': 'بازیگران یوسف پیامبر', 'score': 1.0000001}, {'value': 'پشت صحنه یوسف پیامبر', 'score': 0.875667}, {'value': 'شخصیت\u200cهای یوسف پیامبر', 'score': 0.8651248}, {'value': 'سریال یوسف پیامبر قسمت ۲۶', 'score': 0.83115363}, {'value': 'سریال یوسف پیامبر قسمت ۳', 'score': 0.828628}, {'value': 'سریال یوسف پیامبر قسمت 21', 'score': 0.8218208}, {'value': 'فیلم یوسف پیامبر قسمت ۱۰', 'score': 0.81714165}, {'value': 'فیلم یوسف پیامبر قسمت ۲۷', 'score': 0.81505954}, {'value': 'یوسف پیامبر قسمت اخر', 'score': 0.7982169}, {'value': 'سریال یوسف پیامبر در کدام شهر ساخته شده', 'score': 0.7980849}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=1022, inner_id=1022, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64081, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['بازیگران یوسف پیامبر', 'شخصیت\u200cهای یوسف پیامبر', 'سریال یوسف پیامبر قسمت ۲۶', 'سریال یوسف پیامبر قسمت ۳', 'سریال یوسف پیامبر قسمت 21', 'فیلم یوسف پیامبر قسمت ۱۰', 'فیلم یوسف پیامبر قسمت ۲۷', 'یوسف پیامبر قسمت اخر']}}], score=None, task=1022, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64090, tzinfo=datetime.timezone.utc), id=3071, created_ago='1\xa0day, 17\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0628\\u0627\\u0632\\u06cc\\u06af\\u0631\\u0627\\u0646 \\u06cc\\u0648\\u0633\\u0641 \\u067e\\u06cc\\u0627\\u0645\\u0628\\u0631, \\u0634\\u062e\\u0635\\u06cc\\u062a\\u200c\\u0647\\u0627\\u06cc \\u06cc\\u0648\\u0633\\u0641 \\u067e\\u06cc\\u0627\\u0645\\u0628\\u0631, \\u0633\\u0631\\u06cc\\u0627\\u0644 \\u06cc\\u0648\\u0633\\u0641 \\u067e\\u06cc\\u0627\\u0645\\u0628\\u0631 \\u0642\\u0633\\u0645\\u062a \\u06f2\\u06f6, \\u0633\\u0631\\u06cc\\u0627\\u0644 \\u06cc\\u0648\\u0633\\u0', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905438, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905500, tzinfo=datetime.timezone.utc), data={'query': 'پیام تبریکی عروسی دوست', 'site_count': 25, 'options': [{'value': 'پیام تبریکی عروسی دوست', 'score': 1.0}, {'value': 'متن برای تبریک عروسی', 'score': 0.93884164}, {'value': 'متن تبریک ازدواج دوست صمیمی', 'score': 0.9088291}, {'value': 'تبریک تولد عروس', 'score': 0.90398335}, {'value': 'تبریک عروسی خواهر', 'score': 0.885509}, {'value': 'تبریکی عروسی برادر', 'score': 0.8719386}, {'value': 'برای تبریک ازدواج چی بگم', 'score': 0.8670235}, {'value': 'متن تبریکی ازدواج', 'score': 0.8600306}, {'value': 'تبریک سالگرد ازدواج به دیگران', 'score': 0.84649825}, {'value': 'تبریک ازدواج کوتاه', 'score': 0.8449235}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=1023, inner_id=1023, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64127, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['پیام تبریکی عروسی دوست', 'متن برای تبریک عروسی', 'متن تبریک ازدواج دوست صمیمی', 'متن تبریکی ازدواج', 'برای تبریک ازدواج چی بگم']}}], score=None, task=1023, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64135, tzinfo=datetime.timezone.utc), id=3072, created_ago='1\xa0day, 17\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u067e\\u06cc\\u0627\\u0645 \\u062a\\u0628\\u0631\\u06cc\\u06a9\\u06cc \\u0639\\u0631\\u0648\\u0633\\u06cc \\u062f\\u0648\\u0633\\u062a, \\u0645\\u062a\\u0646 \\u0628\\u0631\\u0627\\u06cc \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0639\\u0631\\u0648\\u0633\\u06cc, \\u0645\\u062a\\u0646 \\u062a\\u0628\\u0631\\u06cc\\u06a9 \\u0627\\u0632\\u062f\\u0648\\u0627\\u062c \\u062f\\u0648\\u0633\\u062a \\u0635\\u0645\\u06cc\\u0645\\u06cc, \\u0645\\u062a\\u0646 \\u062a\\u0628\\u0631\\u06cc\\', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905508, tzinfo=datetime.timezone.utc), updated_by=[]),
#  LseTask(agreement=None, agreement_selected=None, annotations=[], annotations_ids='', annotations_results='', annotators=[], annotators_count=None, avg_lead_time=None, cancelled_annotations=0, comment_authors=[], comment_authors_count=None, comment_count=0, comments=None, completed_at=None, created_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905570, tzinfo=datetime.timezone.utc), data={'query': 'قیمت دلار سکه', 'site_count': 27, 'options': [{'value': 'قیمت سکه و دلار امروز', 'score': 0.9507539}, {'value': 'قیمت دلار ارز سکه طلا', 'score': 0.9447422}, {'value': 'قیمت سکه و ارز', 'score': 0.91923726}, {'value': 'نرخ ارز و سکه', 'score': 0.9191861}, {'value': 'نرخ سکه و ارز', 'score': 0.90805066}, {'value': 'قیمت روز سکه', 'score': 0.8670475}, {'value': 'قیمت\u200cروز سکه', 'score': 0.8670474}, {'value': 'قیمت انواع سکه', 'score': 0.8594568}, {'value': 'نرخ ارز دلار سکه طلا یورو قیمت طلا', 'score': 0.85814875}, {'value': 'قیمت سکه امروز', 'score': 0.8521324}]}, draft_exists=False, drafts=[], file_upload='a5962bf1-annotated_results.json', ground_truth=None, id=1024, inner_id=1024, is_labeled=False, last_comment_updated_at=None, meta={}, overlap=1, precomputed_agreement=None, predictions=[LseTaskPredictionsItem(created_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64202, tzinfo=datetime.timezone.utc), model=None, model_run=None, model_version='undefined', project=1, result=[{'from_name': 'rel', 'to_name': 'q', 'type': 'choices', 'value': {'choices': ['قیمت سکه و دلار امروز', 'قیمت دلار ارز سکه طلا', 'قیمت سکه و ارز', 'نرخ ارز و سکه', 'نرخ سکه و ارز', 'قیمت روز سکه', 'قیمت\u200cروز سکه', 'قیمت سکه امروز']}}], score=None, task=1024, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 25, 64239, tzinfo=datetime.timezone.utc), id=3073, created_ago='1\xa0day, 17\xa0hours', cluster=None, neighbors=None, mislabeling=0.0)], predictions_model_versions='undefined', predictions_results='[{from_name: rel, to_name: q, type: choices, value: {choices: [\\u0642\\u06cc\\u0645\\u062a \\u0633\\u06a9\\u0647 \\u0648 \\u062f\\u0644\\u0627\\u0631 \\u0627\\u0645\\u0631\\u0648\\u0632, \\u0642\\u06cc\\u0645\\u062a \\u062f\\u0644\\u0627\\u0631 \\u0627\\u0631\\u0632 \\u0633\\u06a9\\u0647 \\u0637\\u0644\\u0627, \\u0642\\u06cc\\u0645\\u062a \\u0633\\u06a9\\u0647 \\u0648 \\u0627\\u0631\\u0632, \\u0646\\u0631\\u062e \\u0627\\u0631\\u0632 \\u0648 \\u0633\\u06a9\\u0647, \\u0646\\u0631\\u062e \\u0633\\u06a9\\u0647 \\u0648 \\u0627\\u0631\\u0', predictions_score=None, project=1, review_time=None, reviewed=None, reviewers=None, reviewers_count=None, reviews_accepted=None, reviews_rejected=None, storage_filename=None, total_annotations=0, total_predictions=1, unresolved_comment_count=0, updated_at=datetime.datetime(2025, 11, 10, 14, 9, 24, 905578, tzinfo=datetime.timezone.utc), updated_by=[])]

# %%
task.cancelled_annotations
# Out:
# 0

# %%
new_predictions = [
    "وصل كردن گوشي سامسونگ به تلویزیون",
    "ضبط صوت سامسونگ",
]

predicted_label = li.get_control("rel").label(new_predictions)
score = None

if task.predictions:
    prev_predictions = set(task.predictions[0].result[0]["value"]["choices"])

    common = prev_predictions.intersection(new_predictions)
    union = prev_predictions.union(new_predictions)

    score = len(common) / len(union)

prediction = PredictionValue(
    model_version="mahdi",
    score=score,
    result=[predicted_label],
)

ls_client.predictions.create(task=task.id, **prediction.model_dump())
